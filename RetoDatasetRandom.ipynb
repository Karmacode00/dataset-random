# %%
# !pip install -q streamlit

# %%
import urllib
print("Password/Enpoint IP for localtunnel is:",urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))

# %%
# !npm install localtunnel

# %%
# Importar librerías
import pandas as pd
import numpy as np

# Link archivo
data = '/content/drive/MyDrive/DataReto/sexo_pais_random.xlsx'

# Leer archivo
df = pd.read_excel(data)

# Ver cuantas hojas hay
tabs = pd.ExcelFile(data).sheet_names
print(tabs)
# Out:
# ['2021', '2022', '2023']

# %%
# Leer cada hoja y saltar fila vacía para asignar el encabezado correcto
df1 = pd.read_excel(data, sheet_name='2021', header = 1)
df2 = pd.read_excel(data, sheet_name='2022', header = 1)
df3 = pd.read_excel(data, sheet_name='2023', header = 1)

print(df1.shape)
df1.head()
# Out:
# (498, 10)
#    Pais  Chilena  Venezolana  Boliviana  Colombiana  Peruana  Haitiana  \
# 0  Sexo        0           1          0           0        1         1
# 1   NaN        1           1          0           1        1         1
# 2   NaN        0           1          0           0        1         0
# 3   NaN        1           1          1           1        1         0
# 4   NaN        1           1          1           1        0         1
#
#    Ecuatoriana  Boliviana.1  Argentina
# 0            0            1          0
# 1            0            1          1
# 2            1            0          1
# 3            0            1          1
# 4            0            0          0

# %%
# Eliminar columna repetida "Boliviana"
df1 = df1.drop(df1.filter(regex='\.\d').columns, axis=1)
df2 = df2.drop(df2.filter(regex='\.\d').columns, axis=1)
df3 = df3.drop(df3.filter(regex='\.\d').columns, axis=1)

print(df1.shape)
df1.head()
# Out:
# (498, 9)
#    Pais  Chilena  Venezolana  Boliviana  Colombiana  Peruana  Haitiana  \
# 0  Sexo        0           1          0           0        1         1
# 1   NaN        1           1          0           1        1         1
# 2   NaN        0           1          0           0        1         0
# 3   NaN        1           1          1           1        1         0
# 4   NaN        1           1          1           1        0         1
#
#    Ecuatoriana  Argentina
# 0            0          0
# 1            0          1
# 2            1          1
# 3            0          1
# 4            0          0

# %%
print(df1['Haitiana'].value_counts()[1] + df1['Haitiana'].value_counts()[1])
# Out:
# 516

# %%
# Dashboard

# %%writefile app.py
import streamlit as st
import plotly.express as px
import pandas as pd
import numpy as np
import plotly.graph_objects as go

# Link archivo
data = '/content/drive/MyDrive/DataReto/sexo_pais_random.xlsx'

# Leer archivo
df = pd.read_excel(data)

# Leer cada hoja y saltar fila vacía para asignar el encabezado correcto
df1 = pd.read_excel(data, sheet_name='2021', header = 1)
df2 = pd.read_excel(data, sheet_name='2022', header = 1)
df3 = pd.read_excel(data, sheet_name='2023', header = 1)

# Eliminar columna repetida "Boliviana"
df1 = df1.drop(df1.filter(regex='\.\d').columns, axis=1)
df2 = df2.drop(df2.filter(regex='\.\d').columns, axis=1)
df3 = df3.drop(df3.filter(regex='\.\d').columns, axis=1)

# st_df1 = st.dataframe(df1)
# st_df2 = st.dataframe(df2)
# st_df3 = st.dataframe(df3)


# Título dashboard
st.title('Análisis por Nacionalidad')


# Selector con años
opciones = st.selectbox('Selecciona año', ('2021', '2022', '2023'), index=None, placeholder='Años')

# Grid de columnas
col1, col2, col3 = st.columns([4,4,4], gap='large')

nacionalidades = ['Chilena',	'Venezolana',	'Boliviana',	'Colombiana',	'Peruana',	'Haitiana',	'Ecuatoriana',	'Argentina']

# Caso según año
if opciones == '2021':
   with col1:
      hombres = df1['Chilena'].value_counts()[1] + df1['Venezolana'].value_counts()[1] + df1['Boliviana'].value_counts()[1] + df1['Colombiana'].value_counts()[1] + df1['Peruana'].value_counts()[1] + df1['Haitiana'].value_counts()[1] + df1['Ecuatoriana'].value_counts()[1] + df1['Argentina'].value_counts()[1]
      mujeres = df1['Chilena'].value_counts()[0] + df1['Venezolana'].value_counts()[0] + df1['Boliviana'].value_counts()[0] + df1['Colombiana'].value_counts()[0] + df1['Peruana'].value_counts()[0] + df1['Haitiana'].value_counts()[0] + df1['Ecuatoriana'].value_counts()[1] + df1['Argentina'].value_counts()[0]

      # st.write('Total de hombres y mujeres según año')
      fig = go.Figure(data=[go.Pie(labels=['Hombres', 'Mujeres'], values=[hombres, mujeres], hole=.2)])
      fig.update_layout(title='Total hombres y mujeres')
      fig.update_traces(insidetextorientation='horizontal')
      st.plotly_chart(fig, use_container_width=True)

   with col2:
      hombres_c = df1['Chilena'].value_counts()[1]
      hombres_e = df1['Venezolana'].value_counts()[1] + df1['Boliviana'].value_counts()[1] + df1['Colombiana'].value_counts()[1] + df1['Peruana'].value_counts()[1] + df1['Haitiana'].value_counts()[1] + df1['Ecuatoriana'].value_counts()[1] + df1['Argentina'].value_counts()[1]

      mujeres_c = df1['Chilena'].value_counts()[0]
      mujeres_e = df1['Venezolana'].value_counts()[0] + df1['Boliviana'].value_counts()[0] + df1['Colombiana'].value_counts()[0] + df1['Peruana'].value_counts()[0] + df1['Haitiana'].value_counts()[0] + df1['Ecuatoriana'].value_counts()[1] + df1['Argentina'].value_counts()[0]

      fig = go.Figure(data=[go.Pie(labels=['Chilenos', 'Extranjeros'], values=[hombres_c, hombres_e])])
      fig.update_layout(title='Hombres chilenos')
      st.plotly_chart(fig, use_container_width=True)

      fig = go.Figure(data=[go.Pie(labels=['Chilenas', 'Extranjeras'], values=[mujeres_c, mujeres_e])])
      fig.update_layout(title='Mujeres chilenas')
      st.plotly_chart(fig, use_container_width=True)

   with col3:
     hombres_t = [df1['Chilena'].value_counts()[1], df1['Venezolana'].value_counts()[1], df1['Boliviana'].value_counts()[1], df1['Colombiana'].value_counts()[1], df1['Peruana'].value_counts()[1], df1['Haitiana'].value_counts()[1], df1['Ecuatoriana'].value_counts()[1], df1['Argentina'].value_counts()[1]]
     mujeres_t = [df1['Chilena'].value_counts()[0], df1['Venezolana'].value_counts()[0], df1['Boliviana'].value_counts()[0], df1['Colombiana'].value_counts()[0], df1['Peruana'].value_counts()[0], df1['Haitiana'].value_counts()[0], df1['Ecuatoriana'].value_counts()[1], df1['Argentina'].value_counts()[0]]

     fig = go.Figure(go.Bar(x=hombres_t, y=nacionalidades, orientation='h'))
     fig.update_layout(title='Hombres por nacionalidad')
     st.plotly_chart(fig, use_container_width=True)

     fig = go.Figure(go.Bar(x=mujeres_t, y=nacionalidades, orientation='h'))
     fig.update_layout(title='Mujeres por nacionalidad')
     st.plotly_chart(fig, use_container_width=True)

elif opciones == '2022':
   with col1:
      hombres = df2['Chilena'].value_counts()[1] + df2['Venezolana'].value_counts()[1] + df2['Boliviana'].value_counts()[1] + df2['Colombiana'].value_counts()[1] + df2['Peruana'].value_counts()[1] + df2['Haitiana'].value_counts()[1] + df2['Ecuatoriana'].value_counts()[1] + df2['Argentina'].value_counts()[1]
      mujeres = df2['Chilena'].value_counts()[0] + df2['Venezolana'].value_counts()[0] + df2['Boliviana'].value_counts()[0] + df2['Colombiana'].value_counts()[0] + df2['Peruana'].value_counts()[0] + df2['Haitiana'].value_counts()[0] + df2['Ecuatoriana'].value_counts()[1] + df2['Argentina'].value_counts()[0]

      fig = go.Figure(data=[go.Pie(labels=['Hombres', 'Mujeres'], values=[hombres, mujeres], hole=.2)])
      fig.update_layout(title='Total hombres y mujeres')
      fig.update_traces(insidetextorientation='horizontal')
      st.plotly_chart(fig, use_container_width=True)

   with col2:
      hombres_c = df2['Chilena'].value_counts()[1]
      hombres_e = df2['Venezolana'].value_counts()[1] + df2['Boliviana'].value_counts()[1] + df2['Colombiana'].value_counts()[1] + df2['Peruana'].value_counts()[1] + df2['Haitiana'].value_counts()[1] + df2['Ecuatoriana'].value_counts()[1] + df2['Argentina'].value_counts()[1]

      mujeres_c = df2['Chilena'].value_counts()[0]
      mujeres_e = df2['Venezolana'].value_counts()[0] + df2['Boliviana'].value_counts()[0] + df2['Colombiana'].value_counts()[0] + df2['Peruana'].value_counts()[0] + df2['Haitiana'].value_counts()[0] + df2['Ecuatoriana'].value_counts()[1] + df2['Argentina'].value_counts()[0]

      fig = go.Figure(data=[go.Pie(labels=['Chilenos', 'Extranjeros'], values=[hombres_c, hombres_e])])
      fig.update_layout(title='Hombres chilenos')
      st.plotly_chart(fig, use_container_width=True)

      fig = go.Figure(data=[go.Pie(labels=['Chilenas', 'Extranjeras'], values=[mujeres_c, mujeres_e])])
      fig.update_layout(title='Mujeres chilenas')
      st.plotly_chart(fig, use_container_width=True)

   with col3:
      hombres_t = [df2['Chilena'].value_counts()[1], df2['Venezolana'].value_counts()[1], df2['Boliviana'].value_counts()[1], df2['Colombiana'].value_counts()[1], df2['Peruana'].value_counts()[1], df2['Haitiana'].value_counts()[1], df2['Ecuatoriana'].value_counts()[1], df2['Argentina'].value_counts()[1]]
      mujeres_t = [df2['Chilena'].value_counts()[0], df2['Venezolana'].value_counts()[0], df2['Boliviana'].value_counts()[0], df2['Colombiana'].value_counts()[0], df2['Peruana'].value_counts()[0], df2['Haitiana'].value_counts()[0], df2['Ecuatoriana'].value_counts()[1], df2['Argentina'].value_counts()[0]]

      fig = go.Figure(go.Bar(x=hombres_t, y=nacionalidades, orientation='h'))
      fig.update_layout(title='Hombres por nacionalidad')
      st.plotly_chart(fig, use_container_width=True)

      fig = go.Figure(go.Bar(x=mujeres_t, y=nacionalidades, orientation='h'))
      fig.update_layout(title='Mujeres por nacionalidad')
      st.plotly_chart(fig, use_container_width=True)

elif opciones == '2023':
   with col1:
      hombres = df3['Chilena'].value_counts()[1] + df3['Venezolana'].value_counts()[1] + df3['Boliviana'].value_counts()[1] + df3['Colombiana'].value_counts()[1] + df3['Peruana'].value_counts()[1] + df3['Haitiana'].value_counts()[1] + df3['Ecuatoriana'].value_counts()[1] + df3['Argentina'].value_counts()[1]
      mujeres = df3['Chilena'].value_counts()[0] + df3['Venezolana'].value_counts()[0] + df3['Boliviana'].value_counts()[0] + df3['Colombiana'].value_counts()[0] + df3['Peruana'].value_counts()[0] + df3['Haitiana'].value_counts()[0] + df3['Ecuatoriana'].value_counts()[1] + df3['Argentina'].value_counts()[0]

      fig = go.Figure(data=[go.Pie(labels=['Hombres', 'Mujeres'], values=[hombres, mujeres], hole=.2)])
      fig.update_layout(title='Total hombres y mujeres')
      fig.update_traces(insidetextorientation='horizontal')
      st.plotly_chart(fig, use_container_width=True)

   with col2:
      hombres_c = df3['Chilena'].value_counts()[1]
      hombres_e = df3['Venezolana'].value_counts()[1] + df3['Boliviana'].value_counts()[1] + df3['Colombiana'].value_counts()[1] + df3['Peruana'].value_counts()[1] + df3['Haitiana'].value_counts()[1] + df3['Ecuatoriana'].value_counts()[1] + df3['Argentina'].value_counts()[1]

      mujeres_c = df3['Chilena'].value_counts()[0]
      mujeres_e = df3['Venezolana'].value_counts()[0] + df3['Boliviana'].value_counts()[0] + df3['Colombiana'].value_counts()[0] + df3['Peruana'].value_counts()[0] + df3['Haitiana'].value_counts()[0] + df3['Ecuatoriana'].value_counts()[1] + df3['Argentina'].value_counts()[0]

      fig = go.Figure(data=[go.Pie(labels=['Chilenos', 'Extranjeros'], values=[hombres_c, hombres_e])])
      fig.update_layout(title='Hombres chilenos')
      st.plotly_chart(fig, use_container_width=True)

      fig = go.Figure(data=[go.Pie(labels=['Chilenas', 'Extranjeras'], values=[mujeres_c, mujeres_e])])
      fig.update_layout(title='Mujeres chilenas')
      st.plotly_chart(fig, use_container_width=True)

   with col3:
      hombres_t = [df3['Chilena'].value_counts()[1], df3['Venezolana'].value_counts()[1], df3['Boliviana'].value_counts()[1], df3['Colombiana'].value_counts()[1], df3['Peruana'].value_counts()[1], df3['Haitiana'].value_counts()[1], df3['Ecuatoriana'].value_counts()[1], df3['Argentina'].value_counts()[1]]
      mujeres_t = [df3['Chilena'].value_counts()[0], df3['Venezolana'].value_counts()[0], df3['Boliviana'].value_counts()[0], df3['Colombiana'].value_counts()[0], df3['Peruana'].value_counts()[0], df3['Haitiana'].value_counts()[0], df3['Ecuatoriana'].value_counts()[1], df3['Argentina'].value_counts()[0]]

      fig = go.Figure(go.Bar(x=hombres_t, y=nacionalidades, orientation='h'))
      fig.update_layout(title='Hombres por nacionalidad')
      st.plotly_chart(fig, use_container_width=True)

      fig = go.Figure(go.Bar(x=mujeres_t, y=nacionalidades, orientation='h'))
      fig.update_layout(title='Mujeres por nacionalidad')
      st.plotly_chart(fig, use_container_width=True)

else:
   st.write('Se debe seleccionar un año')
# Out:
# Overwriting app.py

# %%
# !streamlit run app.py --server.address=localhost &>/content/logs.txt &

# %%
# !npx localtunnel --port 8501
